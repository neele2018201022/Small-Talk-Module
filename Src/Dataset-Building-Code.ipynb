# %% [markdown]
# # Loading the dataset

# %%
import pandas as pd
import numpy as np
import json

# %%
dataset=pd.read_csv("credits.csv")

# %%
def get_jokes_dataset(file,temp):
            file.write("tell me a jest on "+temp)
            file.write("\n")
            file.write("tell me something fun about "+temp)
            file.write("\n")
            file.write("say a jest on "+temp)
            file.write("\n")
            file.write("say me something fun about "+temp)
            file.write("\n")
            file.write("crack a jest on "+temp)
            file.write("\n")
            file.write("can u tell a jest about "+temp+"?")
            file.write("\n")
            file.write("jest on "+temp)
            file.write("\n")
            file.write("jest on "+temp)
            file.write("\n")
            file.write("Tell me jest on "+temp+" before i Leave")
            file.write("\n")
            file.write("Tell me jest about "+temp+" before i Leave")
            file.write("\n")
            file.write("another jest maybe on "+temp+"?")
            file.write("\n")
            file.write("jest on "+temp+" please")
            file.write("\n")
            file.write("Can I get another jest on "+temp+" please ?")
            file.write("\n")
            file.write("Can you tell me another jest on "+temp+"?")
            file.write("\n")
            file.write("I would like to hear a jest on "+temp+"!")
            file.write("\n")
            file.write("Give me a jest for "+temp)
            file.write("\n")
            file.write("Do you have a good jest on "+temp+"?")
            file.write("\n")
            file.write("I need to hear a good jest on "+temp+" right now !")
            file.write("\n")
            file.write("Do you know a fun jest about "+temp)
            file.write("\n")
            file.write("Tell me a fun jest on "+temp+" !")
            file.write("\n")
            file.write("Tell me a fun jest about "+temp+" !")
            file.write("\n")
            file.write("Tell me a jest about "+temp)
            file.write("\n")
            file.write("Can you tell me a jest about "+temp+"?")
            file.write("\n")
            file.write("A jest on "+temp+" please")
            file.write("\n")
            file.write("tell me a jest about "+temp+" please")
            file.write("\n")
            file.write("I want a jest on "+temp)
            file.write("\n")
            file.write("can you tell me something fun about "+temp)
            file.write("\n")
            file.write("say something fun on "+temp)
            file.write("\n")
            file.write("I need a fun story on "+temp)
            file.write("\n")
            file.write("How about a jest on "+temp)
            file.write("\n")
            file.write("How about a jest about "+temp)
            file.write("\n")
            file.write("Amuse me on topic "+temp)
            file.write("\n")
            file.write("can you do something fun about "+temp)
            file.write("\n")
            file.write("Something fun about "+temp+" ?")
            file.write("\n")
            file.write("another jest about "+temp+" maybe ?")
            file.write("\n")
            file.write("Can you share with me a kinky jest on "+temp+" ?")
            file.write("\n")
            file.write("I would like to hear a jest on "+temp+"!")
            file.write("\n")
            file.write("jest on "+temp)
            file.write("\n")
            file.write("make me smile by cracking a jest on "+temp)
            file.write("\n")
            file.write("Can you amuse me through a jest on "+temp+"?")
            file.write("\n")
            file.write("Do you have a good jest on "+temp+" ?")
            file.write("\n")
            file.write("just be fun on "+temp+"?")
            file.write("\n")
            file.write("fun story on "+temp)
            file.write("\n")
            file.write("fun story about "+temp)
            file.write("\n")
            file.write("do you know jest about "+temp+" ?")
            file.write("\n")
            file.write("tell me a jest about "+temp )
            file.write("\n")
            file.write("anything fun about "+temp)
            file.write("\n")
            file.write("anything fun on "+temp)  
            file.write("\n")
            file.write("make a jest on "+temp)
            file.write("\n")
            file.write("something about "+temp+" that brings a laugh")
            file.write("\n")
            file.write("next jest on "+temp)
            file.write("\n")
            file.write("something hilarious about "+temp )
            file.write("\n")
            file.write("a one liner fun statement on "+temp)
            file.write("\n")
            file.write("light  "+temp)
            file.write("\n")
            file.write("make this conversation humorous by cracking a jest on "+temp)
            file.write("\n")
            file.write("reduce my stress by cracking a jest on "+temp)
            file.write("\n")
            file.write("help me to relax my brain by cracking a jest on "+temp)
            file.write("\n")
            file.write("say something fun about "+temp)
            file.write("\n")
            file.write("fun fact on "+temp )
            file.write("\n")
            file.write("any fun fact you know about "+temp)
            file.write("\n")

# %%
total_names=[]
for i in range(0,len(dataset)):
    j=(dataset['crew'][i])
    pos=j.find("name")
    flag1=False
    flag2=False
    flag3=False
    name=""
    for i in range(pos,len(j)):
        if(j[i]=='\''):
            if(flag1 and flag2 and flag3):
                break
            if(flag1 and flag2):
                flag3=True
            else:    
                flag1=True
        elif(j[i]==':'):
            flag2=True
        elif(flag3):
            name+=(j[i])
    total_names.append(name) 
file = open('jokes_dataset2.txt', 'w')
counter=1
for name in total_names:
        get_jokes_dataset(file,name)
        counter+=1
        if(counter==5):
                break
file.close()
